# %% [markdown]
# # 5. SEC Annual Reports Extraction
#
# Given the GVKEYs and hence the CIK SEC security keys, that is inter-operable with boardex data,
#
# We will then look at the relevant annual reports

# %% [markdown]
# ### Instructions
#
# Take the metadata from the first step to get the details for the second step!!

# %%
import pandas as pd
import numpy as np
import json

# %%
sec_df = pd.read_csv("sec_gvkey_cik_us_pharma_2022_2024.csv", index_col= 0)

# %%
sec_df
# Out:
#       gvkey                        conm   datadate1   datadate2        cik  \
# 0      1602                   AMGEN INC  1983-03-31  2023-12-31   318154.0
# 1      1979         BALCHEM CORP  -CL B  1974-12-31  2023-12-31     9326.0
# 2      2086    BAXTER INTERNATIONAL INC  1950-12-31  2023-12-31    10456.0
# 3      2403     BRISTOL-MYERS SQUIBB CO  1950-12-31  2023-12-31    14272.0
# 4      2990                  IMUNON INC  1983-09-30  2023-12-31   749647.0
# ..      ...                         ...         ...         ...        ...
# 811  331856                 IMMUNIC INC  2018-12-31  2023-12-31  1280776.0
# 812  332115  ARMATA PHARMACEUTICALS INC  2018-12-31  2023-12-31   921114.0
# 813  347007             IMMUNITYBIO INC  2020-12-31  2023-12-31  1326110.0
# 814  349972   INDAPTUS THERAPEUTICS INC  2020-12-31  2023-12-31  1857044.0
# 815  351038   QUOIN PHARMACEUTICALS LTD  2020-12-31  2023-12-31  1671502.0
#
#     source                        coname      fndate      lndate  n10k  \
# 0    COMPN                     AMGEN INC  1994-03-28  2024-06-04  32.0
# 1    COMPN                  BALCHEM CORP  1995-08-11  2024-05-24  31.0
# 2    COMPN      BAXTER INTERNATIONAL INC  1994-03-21  2024-06-05  34.0
# 3    COMPN       BRISTOL MYERS SQUIBB CO  1994-03-15  2024-05-09  33.0
# 4    COMPN                  IMUNON, INC.  1996-08-07  2024-05-22  38.0
# ..     ...                           ...         ...         ...   ...
# 811  COMPN                 IMMUNIC, INC.  2004-02-18  2024-05-31  11.0
# 812  COMPN  ARMATA PHARMACEUTICALS, INC.  1996-02-06  2024-05-07  33.0
# 813  COMPN             IMMUNITYBIO, INC.  2005-04-29  2024-05-09   9.0
# 814  COMPN   INDAPTUS THERAPEUTICS, INC.  2021-04-20  2024-05-22   3.0
# 815  COMPN   QUOIN PHARMACEUTICALS, LTD.  2016-04-08  2024-05-10   2.0
#
#      n10k_nt  n10k_a  n10q  n10q_nt  n10q_a  ndef    n8k    ntot  flag
# 0        0.0     3.0  95.0      0.0     4.0  92.0  308.0  2936.0   3.0
# 1        0.0     2.0  91.0      0.0     5.0  38.0  194.0  1148.0   3.0
# 2        1.0     3.0  97.0      1.0     5.0  52.0  276.0  2321.0   3.0
# 3        0.0     3.0  98.0      1.0     6.0  64.0  373.0  3304.0   3.0
# 4        1.0     9.0  96.0      3.0     9.0  41.0  300.0  1263.0   3.0
# ..       ...     ...   ...      ...     ...   ...    ...     ...   ...
# 811      0.0     1.0  32.0      0.0     1.0  19.0  139.0   645.0   3.0
# 812      2.0     7.0  82.0      2.0     8.0  43.0  282.0  1062.0   3.0
# 813      0.0     0.0  27.0      0.0     0.0  15.0   64.0   424.0   3.0
# 814      0.0     0.0  10.0      0.0     0.0   6.0   37.0   173.0   3.0
# 815      0.0     0.0   4.0      0.0     0.0   4.0   19.0   417.0   3.0
#
# [816 rows x 19 columns]

# %%
cik_values = sec_df["cik"].dropna().apply(int).astype(str).drop_duplicates().to_list()

# %%
len(cik_values)
# Out:
# 781

# %% [markdown]
# API Query

# %%
import config

API_KEY = config.CREDS["sec_api"]

# %%
from sec_api import QueryApi, ExtractorApi

# %%
def concatenate_to_literal_without_quotes(strings: str):
    """
    Useful function to convert to a string literal
    """

    # Convert each string in the list to be surrounded by single quotes
    quoted_strings = [f"{s}" for s in strings]
    # Join the quoted strings with a comma and space
    joined_strings = ' OR '.join(quoted_strings)
    # Format the joined strings within parentheses
    result = f"({joined_strings})"
    return result

# %%
concatenate_to_literal_without_quotes([1,3])
# Out:
# '(1 OR 3)'

# %%
cik_query = concatenate_to_literal_without_quotes(cik_values)

# %%
cik_query
# Out:
# '(318154 OR 9326 OR 10456 OR 14272 OR 749647 OR 109657 OR 320017 OR 704695 OR 200406 OR 59478 OR 64978 OR 310158 OR 353569 OR 1906324 OR 69499 OR 1792044 OR 73290 OR 275053 OR 78003 OR 217028 OR 101295 OR 786947 OR 730272 OR 791908 OR 1074404 OR 793524 OR 794172 OR 768408 OR 725363 OR 318306 OR 715446 OR 728387 OR 801555 OR 1116463 OR 811641 OR 812796 OR 1555280 OR 787253 OR 818033 OR 1505512 OR 1270073 OR 704562 OR 824166 OR 771856 OR 842023 OR 1293310 OR 1037643 OR 1178711 OR 1551152 OR 1177648 OR 711377 OR 1438533 OR 1388320 OR 855654 OR 1498382 OR 1347858 OR 834365 OR 1533998 OR 1117480 OR 1509261 OR 1368514 OR 1571498 OR 1476963 OR 1478242 OR 1293971 OR 1401708 OR 1439222 OR 1066745 OR 1434868 OR 1130598 OR 1403708 OR 1023024 OR 1356090 OR 1535955 OR 1434316 OR 1410939 OR 1513856 OR 1125345 OR 12239 OR 1337553 OR 1253689 OR 1723128 OR 1429560 OR 1503802 OR 1326732 OR 1384101 OR 1588972 OR 1044378 OR 1515673 OR 1346830 OR 1133869 OR 1567514 OR 1457612 OR 1485003 OR 1412486 OR 1479290 OR 1367920 OR 1580149 OR 1042074 OR 1404644 OR 1583771 OR 827871 OR 1513818 OR 1517022 OR 1273636 OR 1668397 OR 1261249 OR 1341235 OR 1178253 OR 1069899 OR 1598646 OR 1596783 OR 1601485 OR 1267813 OR 1651944 OR 1437402 OR 1395937 OR 1297184 OR 1553643 OR 1582554 OR 1597553 OR 1587221 OR 1521036 OR 1604464 OR 1393434 OR 1501756 OR 1607678 OR 1492674 OR 727207 OR 1023185 OR 1493566 OR 1579823 OR 1478069 OR 1029125 OR 1372514 OR 856984 OR 1566044 OR 1649904 OR 1496671 OR 1506251 OR 1512762 OR 921299 OR 1595097 OR 1610950 OR 1358403 OR 1731348 OR 1583648 OR 57725 OR 1394319 OR 1169987 OR 1522602 OR 1469443 OR 1293818 OR 1626878 OR 1537917 OR 1434647 OR 1610618 OR 1597264 OR 1267565 OR 1339970 OR 872589 OR 1061027 OR 1636050 OR 1454789 OR 874015 OR 1609809 OR 874716 OR 874865 OR 875320 OR 876428 OR 714655 OR 875045 OR 1574235 OR 1641489 OR 925741 OR 1636282 OR 882095 OR 832489 OR 876343 OR 849146 OR 883975 OR 833299 OR 1621443 OR 764195 OR 1629137 OR 948320 OR 854691 OR 1557746 OR 810509 OR 886163 OR 1124105 OR 1422143 OR 1501989 OR 1590877 OR 1534120 OR 1370053 OR 1497504 OR 1640266 OR 1579428 OR 1621221 OR 1492422 OR 1274737 OR 1419554 OR 1642380 OR 1539029 OR 1053691 OR 1649989 OR 1659617 OR 1650664 OR 1358762 OR 1626971 OR 1022899 OR 1305253 OR 1652130 OR 1671584 OR 1453687 OR 1556263 OR 1377121 OR 1604191 OR 1157601 OR 1467154 OR 34956 OR 898437 OR 879407 OR 1651407 OR 1322505 OR 911216 OR 879169 OR 1677940 OR 1348911 OR 1640455 OR 882796 OR 1509745 OR 906709 OR 920465 OR 1590750 OR 1668243 OR 1636651 OR 1160308 OR 1326190 OR 1560241 OR 1404281 OR 1300699 OR 868278 OR 933974 OR 1692415 OR 1442836 OR 1420565 OR 1644963 OR 1676047 OR 1479419 OR 1043961 OR 1705843 OR 1668673 OR 1401914 OR 1626199 OR 1595248 OR 1183765 OR 1585608 OR 1680048 OR 1711279 OR 1603454 OR 1527599 OR 1654151 OR 1513525 OR 1494650 OR 1069308 OR 1701108 OR 1624658 OR 1604950 OR 1645460 OR 1768224 OR 1714899 OR 1717452 OR 1533743 OR 1035354 OR 1682639 OR 1707502 OR 1390478 OR 1281895 OR 1570562 OR 1720893 OR 1173281 OR 1551986 OR 72444 OR 1724521 OR 1527728 OR 1661998 OR 1718108 OR 1463361 OR 1694665 OR 1727196 OR 1698530 OR 1690585 OR 1660334 OR 1595585 OR 1645666 OR 1674365 OR 1681087 OR 1867096 OR 1737953 OR 1709401 OR 1564824 OR 1658247 OR 1398733 OR 1695357 OR 1205922 OR 1819576 OR 1614067 OR 1739104 OR 1710340 OR 1724344 OR 1889109 OR 1382101 OR 1655759 OR 1711754 OR 1656634 OR 1576280 OR 1468748 OR 1722964 OR 1739426 OR 1737287 OR 1746466 OR 1169245 OR 1426332 OR 1581280 OR 1664106 OR 1682852 OR 1708599 OR 1661181 OR 1711786 OR 1728117 OR 1708493 OR 1750019 OR 1661460 OR 1653087 OR 1644903 OR 1751299 OR 1017491 OR 1755237 OR 1357874 OR 1472091 OR 1595893 OR 1760542 OR 1642375 OR 1772028 OR 1563880 OR 1633070 OR 1661059 OR 1697532 OR 1662774 OR 1605888 OR 1676725 OR 1659352 OR 1527753 OR 1623526 OR 1743881 OR 1744659 OR 1532346 OR 1478320 OR 1679363 OR 1771917 OR 1739614 OR 1260990 OR 1759425 OR 1680581 OR 1729427 OR 1477845 OR 1725430 OR 1673772 OR 1615219 OR 1773427  ...

# %% [markdown]
# 1. Basic filing to get a 10K report
#
# Write for loop if greater than 10k filings
#
# https://sec-api.io/docs/query-api

# %%
# cik_values

# %%
queryApi = QueryApi(api_key=API_KEY)#"YOUR_API_KEY")

# %%
query = {
    # "query": f"cik:{cik_query} AND formType:\"10-K\"",
    # "query": "cik:1050122 AND formType:\"10-K\"",
    "query": "cik:730469 AND formType:\"10-K\"",
    # "query": "cik:(1176334 OR 1413898 OR 99780) AND formType:\"10-K\"",
    # "query": "cik:(0001050122) AND formType:\"10-K\"",
    "from": "0",
    "size": "50",
    "sort": [{ "filedAt": { "order": "desc" } }]
}

filings = queryApi.get_filings(query)
filings
# Out:
# {'total': {'value': 21, 'relation': 'eq'},
#  'query': {'from': 0, 'size': 50},
#  'filings': [{'ticker': 'ALO',
#    'formType': '10-K',
#    'accessionNo': '0000730469-08-000102',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/alpharmainc_10k.htm',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/0000730469-08-000102.txt',
#    'filedAt': '2008-02-27T14:45:30-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '664750',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/alpharmainc_10k.htm',
#      'description': 'ALPHARMA INC 10-K 2007',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '45613',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex10_11b.htm',
#      'description': 'EXHIBIT 10.11B',
#      'type': 'EX-10'},
#     {'sequence': '3',
#      'size': '4087',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex10_11c.htm',
#      'description': 'EXHIBIT10.11C',
#      'type': 'EX-10'},
#     {'sequence': '4',
#      'size': '55292',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex10_35.htm',
#      'description': 'VENTIVE COMMERCIAL SERVICES - SERVICES AGMT - 12.17.07',
#      'type': 'EX-10'},
#     {'sequence': '5',
#      'size': '84382',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex10_36.htm',
#      'description': '2003 OMNIBUS PLAN - AMENDED AND RESTATED EFFECTIVE 1.01.08',
#      'type': 'EX-10'},
#     {'sequence': '6',
#      'size': '57907',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex10_39.htm',
#      'description': '2005 SUPPLEMENTAL SAVINGS PLAN AMENDED AND RESTATED EFFECTIVE 1-1-08',
#      'type': 'EX-10'},
#     {'sequence': '7',
#      'size': '43432',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex10_40.htm',
#      'description': 'SUPPLEMENTAL SAVINGS PLAN - EFFECTIVE 1-01-2008',
#      'type': 'EX-10'},
#     {'sequence': '8',
#      'size': '34593',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex10_45.htm',
#      'description': 'AMENDED AND RESTATED SEVERANCE PLAN',
#      'type': 'EX-10'},
#     {'sequence': '9',
#      'size': '42781',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex10_46.htm',
#      'description': 'AMENDED AND RESTATED CHANGE IN CONTROL PLAN.',
#      'type': 'EX-10'},
#     {'sequence': '10',
#      'size': '14950',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex10_48.htm',
#      'description': 'SUPPLEMENTAL PENSION PLAN - AMENDED AND RESTATED 1-01-2008',
#      'type': 'EX-10'},
#     {'sequence': '11',
#      'size': '54560',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex10_50.htm',
#      'description': 'SUPPLEMENTAL SAVINGS PLAN AMENDED AND RESTATED EFFECTIVE JANAURY 1, 2008',
#      'type': 'EX-10'},
#     {'sequence': '12',
#      'size': '25672',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex10_52.htm',
#      'description': 'EXHIBIT10.52',
#      'type': 'EX-10'},
#     {'sequence': '13',
#      'size': '3876',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex21.htm',
#      'description': '2008 EXHIBIT 21 SUBSIDIARY LIST',
#      'type': 'EX-21'},
#     {'sequence': '14',
#      'size': '1259',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex23_1.htm',
#      'description': 'CONSENT OF INDEPENDENT REGISTERED PUBLIC ACCOUNTING FIRM',
#      'type': 'EX-23'},
#     {'sequence': '15',
#      'size': '4792',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex31_1.htm',
#      'description': '302 CERTIFICATION-CEO.10K-07',
#      'type': 'EX-31'},
#     {'sequence': '16',
#      'size': '4797',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex31_2.htm',
#      'description': '302 CERTIFICATION-CFO.10K-07',
#      'type': 'EX-31'},
#     {'sequence': '17',
#      'size': '2587',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/ex32.htm',
#      'description': '906 CERTIFICATIONS.10-K-07',
#      'type': 'EX-32'},
#     {'sequence': '\xa0',
#      'size': '1147023',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/0000730469-08-000102.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '0000730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': '10-K',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '08646216'}],
#    'id': '41ee076a4f72e92baf910c2a549ef5c9',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-08-000102-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [],
#    'periodOfReport': '2007-12-31'},
#   {'ticker': 'ALO',
#    'formType': '10-K',
#    'accessionNo': '0000730469-07-000017',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/alo10k2006.htm',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/0000730469-07-000017.txt',
#    'filedAt': '2007-03-01T15:38:30-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '677422',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/alo10k2006.htm',
#      'description': 'FORM 10K - DECEMBER 31, 2006',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '49543',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit3_2.htm',
#      'description': 'AMENDED AND RESTATED BY-LAWS OF THE COMPANY',
#      'type': 'EX-3.2'},
#     {'sequence': '3',
#      'size': '17363',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_1a.htm',
#      'description': 'AMENDED AND RESTATED LOAN AND SECURITY AGREEMENT',
#      'type': 'EX-10.1A'},
#     {'sequence': '4',
#      'size': '11707',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_1b.htm',
#      'description': 'AMENDED AND RESTATED LOAN AND SECURITY AGREEMENT',
#      'type': 'EX-10.1B'},
#     {'sequence': '5',
#      'size': '6133',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_5a.htm',
#      'description': 'AGREEMENT ON THE SUCCESSION OF PENSION OBLIGATIONS',
#      'type': 'EX-10.5A'},
#     {'sequence': '6',
#      'size': '17314',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_12a.htm',
#      'description': 'SEPARATION AGREEMENT',
#      'type': 'EX-10.12A'},
#     {'sequence': '7',
#      'size': '9012',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_25a.htm',
#      'description': 'AMENDMENT AGREEMENT',
#      'type': 'EX-10.25A'},
#     {'sequence': '8',
#      'size': '1316',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_27a.htm',
#      'description': 'AMENDMENT NO. 1 TO THE 2003 OMNIBUS INCENTIVE COMP. PLAN',
#      'type': 'EX-10.27A'},
#     {'sequence': '9',
#      'size': '2012',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_27b.htm',
#      'description': 'AMENDMENT NO. 2 TO THE 2003 OMNIBUS INCENTIVE COMP. PLAN',
#      'type': 'EX-10.27B'},
#     {'sequence': '10',
#      'size': '2745',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_27c.htm',
#      'description': 'AMENDMENT NO. 3 TO THE 2003 OMNIBUS INCENTIVE COMP. PLAN',
#      'type': 'EX-10.27C'},
#     {'sequence': '11',
#      'size': '19955',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_28.htm',
#      'description': 'AMENDED ALPHARMA INC. EXECUTIVE BONUS PLAN',
#      'type': 'EX-10.28'},
#     {'sequence': '12',
#      'size': '2263',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_29a.htm',
#      'description': 'AMENDMENT-1997 INCENTIVE STOCK OPTION AND APPRECIATION RIGHT PLAN',
#      'type': 'EX-10.29A'},
#     {'sequence': '13',
#      'size': '1370',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_29b.htm',
#      'description': 'AMENDMENT-1997 INCENTIVE STOCK OPTION AND APPRECIATION RIGHT PLAN',
#      'type': 'EX-10.29B'},
#     {'sequence': '14',
#      'size': '55999',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_31.htm',
#      'description': '2005 SUPPLEMENTAL SAVINGS PLAN',
#      'type': 'EX-10.31'},
#     {'sequence': '15',
#      'size': '1615',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_31a.htm',
#      'description': 'AMENDMENT - 2005 SUPPLEMENTAL SAVINGS PLAN',
#      'type': 'EX-10.31A'},
#     {'sequence': '16',
#      'size': '2655',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_31b.htm',
#      'description': 'AMENDMENT NO. 1 SUPPLEMENTAL SAVINGS PLAN',
#      'type': 'EX-10.31B'},
#     {'sequence': '17',
#      'size': '43568',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_32.htm',
#      'description': '2007 SUPPLEMENTAL SAVINGS PLAN',
#      'type': 'EX-10.32'},
#     {'sequence': '18',
#      'size': '32904',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_37.htm',
#      'description': 'SEVERANCE PLAN AMENDED AND RESTATED',
#      'type': 'EX-10.37'},
#     {'sequence': '19',
#      'size': '38211',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_38.htm',
#      'description': 'CHANGE IN CONTROL PLAN',
#      'type': 'EX-10.38'},
#     {'sequence': '20',
#      'size': '2980',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_39b.htm',
#      'description': 'AMENDMENT TO THE DEFERRED COMPENSATION PLAN',
#      'type': 'EX-10.39B'},
#     {'sequence': '21',
#      'size': '16845',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_40.htm',
#      'description': 'A.L. PHARMA INC. SUPPLEMENTAL PENSION PLAN',
#      'type': 'EX-10.40'},
#     {'sequence': '22',
#      'size': '1482',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_40a.htm',
#      'description': 'AMENDMENT NO. 1 - A.L. PHARMA SUPPLEMENTAL PENSION PLAN',
#      'type': 'EX-10.40A'},
#     {'sequence': '23',
#      'size': '3171',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_40b.htm',
#      'description': 'AMENDMENT NO. 2 - ALPHARMA INC. SUPPLEMENTAL PENSION PLAN',
#      'type': 'EX-10.40B'},
#     {'sequence': '24',
#      'size': '17319',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_41.htm',
#      'description': 'NON-EMPLOYEE DIRECTOR OPTION PLAN',
#      'type': 'EX-10.41'},
#     {'sequence': '25',
#      'size': '2177',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_41a.htm',
#      'description': 'AMENDMENT TO THE NON-EMPLOYEE DIRECTOR OPTION PLAN',
#      'type': 'EX-10.41A'},
#     {'sequence': '26',
#      'size': '53664',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_42.htm',
#      'description': 'SUPPLEMENTAL SAVINGS PLAN',
#      'type': 'EX-10.42'},
#     {'sequence': '27',
#      'size': '1593',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_42a.htm',
#      'description': 'AMENDMENT NO. 1 SUPPLEMENTAL SAVINGS PLAN',
#      'type': 'EX-10.42A'},
#     {'sequence': '28',
#      'size': '2997',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit10_42b.htm',
#      'description': 'AMENDMENT NO. 2 SUPPLEMENTAL SAVINGS PLAN',
#      'type': 'EX-10.42B'},
#     {'sequence': '29',
#      'size': '4429',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit21.htm',
#      'description': 'LIST OF SUBSIDIARIES',
#      'type': 'EX-21'},
#     {'sequence': '30',
#      'size': '1306',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit23_1.htm',
#      'description': 'CONSENT OF PRICEWATERHOUSECOOPERS LLP',
#      'type': 'EX-23.1'},
#     {'sequence': '31',
#      'size': '1218',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit23_2.htm',
#      'description': 'CONSENT OF BDO SEIDMAN LLP',
#      'type': 'EX-23.2'},
#     {'sequence': '32',
#      'size': '4406',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit31_1ceo.htm',
#      'description': 'CERTIFICATION - SECTION 302',
#      'type': 'EX-31'},
#     {'sequence': '33',
#      'size': '4432',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit31_2cfo.htm',
#      'description': 'CERTIFICATION - SECTION 302',
#      'type': 'EX-31'},
#     {'sequence': '34',
#      'size': '1811',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/exhibit32.htm',
#      'description': 'CERTIFICATION - SECTION 906',
#      'type': 'EX-32'},
#     {'sequence': '\xa0',
#      'size': '1114551',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046907000017/0000730469-07-000017.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '0000730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': '10-K',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '07663136'}],
#    'id': '599983dbc4a2954080d15cc931763cfb',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-07-000017-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [],
#    'periodOfReport': '2006-12-31'},
#   {'ticker': 'ALO',
#    'formType': '10-K',
#    'accessionNo': '0000730469-06-000027',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/alo10k2005.htm',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/0000730469-06-000027.txt',
#    'filedAt': '2006-03-16T14:43:08-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '781389',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/alo10k2005.htm',
#      'description': 'FORM 10-K',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '590296',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_2.htm',
#      'description': 'LOAN AND SECURITY AGREEMENT',
#      'type': 'EX-10.2'},
#     {'sequence': '3',
#      'size': '2071',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_4.htm',
#      'description': 'PROMISSORY NOTE',
#      'type': 'EX-10.4'},
#     {'sequence': '4',
#      'size': '33227',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_12a.htm',
#      'description': 'RETENTION AGREEMENT',
#      'type': 'EX-10.12A'},
#     {'sequence': '5',
#      'size': '85219',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_31.htm',
#      'description': 'TOLL MANUFACTURING AGREEMENT',
#      'type': 'EX-10.31'},
#     {'sequence': '6',
#      'size': '2211',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_33a.htm',
#      'description': 'AMENDENT TO ALPHARMA INC. EXECUTIVE BONUS PLAN',
#      'type': 'EX-10.33A'},
#     {'sequence': '7',
#      'size': '31057',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_35.htm',
#      'description': 'ALPHARMA INC. EMPLOYEE STOCK PURCHASE PLAN',
#      'type': 'EX-10.35'},
#     {'sequence': '8',
#      'size': '3228',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_37a.htm',
#      'description': 'AMENDMENT NO. 1 TO ALPHARMA INC. 2005 SUPPLEMENTAL SAVINGS PLAN',
#      'type': 'EX-10.37A'},
#     {'sequence': '9',
#      'size': '30739',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_42.htm',
#      'description': 'ALPHARMA INC. SEVERANCE PLAN',
#      'type': 'EX-10.42'},
#     {'sequence': '10',
#      'size': '38624',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_43.htm',
#      'description': 'ALPHARMA INC. CHANGE IN CONTROL PLAN',
#      'type': 'EX-10.43'},
#     {'sequence': '11',
#      'size': '18506',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_46.htm',
#      'description': 'ALPHARMA INC. AMENDED AND RESTATED DEFERRED COMPENSATION PLAN',
#      'type': 'EX-10.46'},
#     {'sequence': '12',
#      'size': '1889',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_46a.htm',
#      'description': 'AMENDMENT NO. 1 TO THE ALPHARMA INC. AMENDED AND RESTATED DEFERRED COMPENSATION',
#      'type': 'EX-10.46A'},
#     {'sequence': '13',
#      'size': '11276',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_47.htm',
#      'description': 'A.L. PHARMA INC. SUPPLEMENTAL PENSION PLAN',
#      'type': 'EX-10.47'},
#     {'sequence': '14',
#      'size': '2437',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_47a.htm',
#      'description': 'FIRST AMENDMENT TO ALPHARMA INC. SUPPLEMENTAL PENSION PLAN',
#      'type': 'EX-10.47A'},
#     {'sequence': '15',
#      'size': '2984',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh10_47b.htm',
#      'description': 'SECOND AMENDMENT TO ALPHARMA INC. SUPPLEMENTAL PENSION PLAN',
#      'type': 'EX-10.47B'},
#     {'sequence': '16',
#      'size': '4422',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh21.htm',
#      'description': 'LIST OF SUBSIDIARIES OF REGISTRANT',
#      'type': 'EX-21'},
#     {'sequence': '17',
#      'size': '1251',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh23_1.htm',
#      'description': 'CONSENT',
#      'type': 'EX-23.1'},
#     {'sequence': '18',
#      'size': '1061',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/exh23_2.htm',
#      'description': 'CONSENT',
#      'type': 'EX-23.2'},
#     {'sequence': '19',
#      'size': '4438',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/alo302ceo.htm',
#      'description': 'CERTIFICATION OF CHIEF EXECUTIVE OFFICER',
#      'type': 'EX-31.1'},
#     {'sequence': '20',
#      'size': '4563',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/alo302cfo.htm',
#      'description': 'CERTIFICATION OF CHIEF FINANCIAL OFFICER',
#      'type': 'EX-31.2'},
#     {'sequence': '21',
#      'size': '1760',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/alo906.htm',
#      'description': 'CERTIFICATION OF PRINCIPAL EXECUTIVE OFFICER AND THE PRINCIPAL FINANCIAL OFFICER',
#      'type': 'EX-32'},
#     {'sequence': '\xa0',
#      'size': '1654484',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046906000027/0000730469-06-000027.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '0000730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': '10-K',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '06691387'}],
#    'id': '8f430383e62c4dfa91780580913ae82a',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-06-000027-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [],
#    'periodOfReport': '2005-12-31'},
#   {'ticker': 'ALO',
#    'formType': '10-K/A',
#    'accessionNo': '0000730469-05-000035',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000035/alo10ka2004.htm',
#    'description': 'Form 10-K/A - Annual report [Section 13 and 15(d), not S-K Item 405]: [Amend]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000035/0000730469-05-000035.txt',
#    'filedAt': '2005-05-05T13:59:07-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '1004346',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000035/alo10ka2004.htm',
#      'description': 'FORM 10K/A',
#      'type': '10-K/A'},
#     {'sequence': '2',
#      'size': '4410',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000035/ceo302.htm',
#      'description': 'CERTIFICATION',
#      'type': 'EX-31.1'},
#     {'sequence': '3',
#      'size': '4442',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000035/cfo302.htm',
#      'description': 'CERTIFICATION',
#      'type': 'EX-31.2'},
#     {'sequence': '4',
#      'size': '1634',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000035/alo906cert.htm',
#      'description': 'CERTIFICATION',
#      'type': 'EX-32'},
#     {'sequence': '\xa0',
#      'size': '1016510',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000035/0000730469-05-000035.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '0000730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': '10-K/A',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '05802746'}],
#    'id': '52bc982b2aa46cf5b785740bd1823d94',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-05-000035-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [],
#    'periodOfReport': '2004-12-31'},
#   {'ticker': 'ALO',
#    'formType': '10-K/A',
#    'accessionNo': '0000950123-05-005332',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000095012305005332/y08364e10vkza.txt',
#    'description': 'Form 10-K/A - Annual report [Section 13 and 15(d), not S-K Item 405]: [Amend]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000095012305005332/0000950123-05-005332.txt',
#    'filedAt': '2005-04-29T17:02:49-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '90620',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000095012305005332/y08364e10vkza.txt',
#      'description': 'FORM 10-K/A',
#      'type': '10-K/A'},
#     {'sequence': '2',
#      'size': '4005',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000095012305005332/y08364exv31w1.txt',
#      'description': 'CERTIFICATION',
#      'type': 'EX-31.1'},
#     {'sequence': '3',
#      'size': '4088',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000095012305005332/y08364exv31w2.txt',
#      'description': 'CERTIFICATION',
#      'type': 'EX-31.2'},
#     {'sequence': '4',
#      'size': '1706',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000095012305005332/y08364exv32.txt',
#      'description': 'CERTIFICATIONS',
#      'type': 'EX-32'},
#     {'sequence': '\xa0',
#      'size': '101939',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000095012305005332/0000950123-05-005332.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '0000730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': '10-K/A',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '05786981'}],
#    'id': 'bedf1c208f4012019f9ef1cb19824940',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000950123-05-005332-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [],
#    'periodOfReport': '2004-12-30'},
#   {'ticker': 'ALO',
#    'formType': '10-K',
#    'accessionNo': '0000730469-05-000021',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/alo10k2004final.htm',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/0000730469-05-000021.txt',
#    'filedAt': '2005-03-31T16:58:50-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '1109175',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/alo10k2004final.htm',
#      'description': 'FORM 10-K',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '36154',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_1h.htm',
#      'description': 'AMENDMENT NO. 6 TO THE CREDIT AGREEMENT',
#      'type': 'EX-10.1H'},
#     {'sequence': '3',
#      'size': '1575',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_7a.htm',
#      'description': 'AMENDMENT NO. 1 TO SISSENER EMPLOYMENT LETTER',
#      'type': 'EX-10.7A'},
#     {'sequence': '4',
#      'size': '13090',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_21.htm',
#      'description': 'ADMINISTRATIVE SERVICES AGREEMENT',
#      'type': 'EX-10.21'},
#     {'sequence': '5',
#      'size': '81944',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_35b.htm',
#      'description': 'SETTLEMENT AND LICENCE AGREEMENT',
#      'type': 'EX-10.35B'},
#     {'sequence': '6',
#      'size': '4885',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_37a.htm',
#      'description': 'AMENDMENT TO THE AMENDED AND RESTATED SUPPLY AGREEMENT',
#      'type': 'EX-10.37A'},
#     {'sequence': '7',
#      'size': '9107',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_38c.htm',
#      'description': 'SECOND AMENDMENT FO SELECTIVE WAIVER AGREEMENT',
#      'type': 'EX-10.38C'},
#     {'sequence': '8',
#      'size': '155999',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_40.htm',
#      'description': 'AGREEMENT BETWEEN PUREPAC PHARMACEUTICAL CO. AND ORCHID CHEMICALS & PHARMACEUTIC',
#      'type': 'EX-10.40'},
#     {'sequence': '9',
#      'size': '15877',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_41.htm',
#      'description': 'SETTLEMENT AGREEMENT',
#      'type': 'EX-10.41'},
#     {'sequence': '10',
#      'size': '52836',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_42.htm',
#      'description': '2005 SUPPLEMENTAL SAVINGS PLAN',
#      'type': 'EX-10.42'},
#     {'sequence': '11',
#      'size': '35141',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_43.htm',
#      'description': 'FORM OF RESTRICTED STOCK AWARD AGREEMENT',
#      'type': 'EX-10.43'},
#     {'sequence': '12',
#      'size': '25049',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_44.htm',
#      'description': 'FORM OF RESTRICTED STOCK UNIT AWARD AGREEMENT FOR BOARD OF DIRECTORS',
#      'type': 'EX-10.44'},
#     {'sequence': '13',
#      'size': '27988',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_45.htm',
#      'description': 'FORM OF RESTRICTED STOCK UNIT AWARD AGREEMENT FOR EMPLOYEES OUTSIDE OF THE U.S.',
#      'type': 'EX-10.45'},
#     {'sequence': '14',
#      'size': '23624',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_46.htm',
#      'description': 'FORM OF NON-QUALIFIED STOCK OPTION AWARD AGREEMENT',
#      'type': 'EX-10.46'},
#     {'sequence': '15',
#      'size': '27033',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex10_47.htm',
#      'description': 'FORM OF PERFORMANCE UNIT AWARD AGREEMENT',
#      'type': 'EX-10.47'},
#     {'sequence': '16',
#      'size': '11947',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex12.htm',
#      'description': 'COMPUTATION OF THE RATIO OF EARNINGS',
#      'type': 'EX-12'},
#     {'sequence': '17',
#      'size': '5988',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex21.htm',
#      'description': 'LIST OF SUBSIDIARIES',
#      'type': 'EX-21'},
#     {'sequence': '18',
#      'size': '945',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex23consent.htm',
#      'description': 'CONSENT OF AUDITORS',
#      'type': 'EX-23'},
#     {'sequence': '19',
#      'size': '4396',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex31_1302ceo.htm',
#      'description': 'SECTION 302 CERTIFICATION OF THE CHIEF EXECUTIVE OFFICER',
#      'type': 'EX-31.1'},
#     {'sequence': '20',
#      'size': '4258',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex31_2302cfo.htm',
#      'description': 'SECTION 302 CERTIFICATION OF THE CHIEF FINANCIAL OFFICER',
#      'type': 'EX-31.2'},
#     {'sequence': '21',
#      'size': '1540',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/ex32_906.htm',
#      'description': 'SECTION 906 CERTIFICATION',
#      'type': 'EX-32'},
#     {'sequence': '\xa0',
#      'size': '1653056',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000021/0000730469-05-000021.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '0000730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': '10-K',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '05721367'}],
#    'id': '26c9652debd84ff3866009d9e518c0ad',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-05-000021-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [],
#    'periodOfReport': '2004-12-31'},
#   {'ticker': 'ALO',
#    'formType': 'NT 10-K',
#    'accessionNo': '0000730469-05-000019',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000019/alo12b-25.htm',
#    'description': 'Form NT 10-K - Notification of inability to timely file Form 10-K 405, 10-K, 10-KSB 405, 10-KSB, 10-KT, or 10-KT405',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000019/0000730469-05-000019.txt',
#    'filedAt': '2005-03-15T13:57:46-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '16701',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000019/alo12b-25.htm',
#      'description': 'FORM 12B-25',
#      'type': 'NT 10-K'},
#     {'sequence': '\xa0',
#      'size': '18330',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000019/0000730469-05-000019.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '0000730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': 'NT 10-K',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '05681026'}],
#    'id': '7264478227c31517bd9e505514f3f285',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-05-000019-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [],
#    'periodOfReport': '2004-12-31'},
#   {'ticker': 'ALO',
#    'formType': '10-K/A',
#    'accessionNo': '0000730469-05-000003',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000003/alo10ka2003_restate2.htm',
#    'description': 'Form 10-K/A - Annual report [Section 13 and 15(d), not S-K Item 405]: [Amend]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000003/0000730469-05-000003.txt',
#    'filedAt': '2005-01-12T13:57:06-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '1103006',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000003/alo10ka2003_restate2.htm',
#      'description': 'FORM 10K/A DECEMBER 31, 2003',
#      'type': '10-K/A'},
#     {'sequence': '2',
#      'size': '7705',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000003/alo302cert10ka_2003.htm',
#      'type': 'EX-31.0'},
#     {'sequence': '3',
#      'size': '1646',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000003/alo906cert10ka_2003.htm',
#      'type': 'EX-32.0'},
#     {'sequence': '\xa0',
#      'size': '1114177',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046905000003/0000730469-05-000003.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '0000730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': '10-K/A',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '05525479'}],
#    'id': '7ae535c75ac70562aa14f9eef267d84f',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-05-000003-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [],
#    'periodOfReport': '2003-12-31'},
#   {'ticker': 'ALO',
#    'formType': '10-K/A',
#    'accessionNo': '0000730469-04-000075',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000075/alo10ka2003.htm',
#    'description': 'Form 10-K/A - Annual report [Section 13 and 15(d), not S-K Item 405]: [Amend]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000075/0000730469-04-000075.txt',
#    'filedAt': '2004-06-01T14:40:52-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '970987',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000075/alo10ka2003.htm',
#      'type': '10-K/A'},
#     {'sequence': '2',
#      'size': '12244',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000075/exhibit12.htm',
#      'type': 'EX-12'},
#     {'sequence': '3',
#      'size': '932',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000075/exhibit23.htm',
#      'type': 'EX-23'},
#     {'sequence': '4',
#      'size': '7919',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000075/alo302.htm',
#      'type': 'EX-31.2'},
#     {'sequence': '5',
#      'size': '1753',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000075/alo906.htm',
#      'type': 'EX-32'},
#     {'sequence': '\xa0',
#      'size': '995719',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000075/0000730469-04-000075.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '0000730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': '10-K/A',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '04840892'}],
#    'id': 'b5838a47ccdefb3384d813f9a9656c24',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-04-000075-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [],
#    'periodOfReport': '2003-12-31'},
#   {'ticker': 'ALO',
#    'formType': '10-K',
#    'accessionNo': '0000730469-04-000058',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/alo10k2003master.htm',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/0000730469-04-000058.txt',
#    'filedAt': '2004-03-12T14:06:01-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '941652',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/alo10k2003master.htm',
#      'description': 'FORM 10-K',
#      'type': '10-K'},
#     {'sequence': '3',
#      'size': '49877',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/exhibit10-1e.htm',
#      'description': 'AMENDMENT NO. 3 TO THE CREDIT AGREEMENT',
#      'type': 'EX-10.1E'},
#     {'sequence': '4',
#      'size': '8042',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/exhibit10-14b.htm',
#      'description': 'SUPPLEMENTAL LETTER AGREEMENT',
#      'type': 'EX-10.14B'},
#     {'sequence': '5',
#      'size': '29487',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/exhibit10-18a.htm',
#      'description': 'AMENDED AND RESTATED ALPHARMA INC. SEVERANCE PLAN',
#      'type': 'EX-10.18A'},
#     {'sequence': '6',
#      'size': '34598',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/exhibit10-19a.htm',
#      'description': 'AMENDED AND RESTATED ALPHARMA INC. CHANGE IN CONTROL PLAN',
#      'type': 'EX-10.19A'},
#     {'sequence': '7',
#      'size': '19630',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/exhibit10-20a.htm',
#      'description': 'AMENDED AND RESTATED ALPHARMA INC. EXECUTIVE BONUS PLAN',
#      'type': 'EX-10.20A'},
#     {'sequence': '8',
#      'size': '43850',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/exhibit10-29.htm',
#      'description': 'SETTLEMENT AGREEMENT',
#      'type': 'EX-10.29'},
#     {'sequence': '9',
#      'size': '11263',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/exhibit10-34a.htm',
#      'description': 'SEPARATION LETTER AGREEMENT',
#      'type': 'EX-10.34A'},
#     {'sequence': '10',
#      'size': '12249',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/exhibit12.htm',
#      'description': 'RATIO OF EARNINGS TO FIXED CHARGES',
#      'type': 'EX-12'},
#     {'sequence': '11',
#      'size': '5989',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/exhibit21.htm',
#      'description': 'LIST OF SUBSIDIARIES',
#      'type': 'EX-21'},
#     {'sequence': '12',
#      'size': '892',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/consent2003-10k.htm',
#      'description': 'CONSENT OF PRICEWATERHOUSECOOPERS LLP',
#      'type': 'EX-23'},
#     {'sequence': '13',
#      'size': '4157',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/exhibit31-1iw.htm',
#      'description': 'CERTIFICATION OF CHIEF EXECUTIVE OFFICER',
#      'type': 'EX-31.1'},
#     {'sequence': '14',
#      'size': '4100',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/exhibit31-2mf.htm',
#      'description': 'CERTIFICATION OF CHIEF FINANICAL OFFICER',
#      'type': 'EX-31.2'},
#     {'sequence': '15',
#      'size': '1564',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/exhibit32mf.htm',
#      'description': 'CERTIFICATION OF PRINCIPAL EXECUTIVE OFFICE AND THE PRINCIPAL FINANCIAL OFFICER',
#      'type': 'EX-32'},
#     {'sequence': '\xa0',
#      'size': '1170821',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000058/0000730469-04-000058.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '0000730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': '10-K',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '04665519'}],
#    'id': 'c0f9b33b2ff66adf49e8597d38e8583e',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-04-000058-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [],
#    'periodOfReport': '2003-12-31'},
#   {'ticker': 'ALO',
#    'formType': '10-K/A',
#    'accessionNo': '0000730469-04-000019',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000019/alo10ka2002.htm',
#    'description': 'Form 10-K/A - Annual report [Section 13 and 15(d), not S-K Item 405]: [Amend]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000019/0000730469-04-000019.txt',
#    'filedAt': '2004-02-27T14:21:15-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '803414',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000019/alo10ka2002.htm',
#      'description': 'FORM 10K/A',
#      'type': '10-K/A'},
#     {'sequence': '3',
#      'size': '1029',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000019/consentexhibit23.htm',
#      'description': 'EXHIBIT 23',
#      'type': 'EX-23'},
#     {'sequence': '4',
#      'size': '3456',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000019/alo90610ka2002.htm',
#      'type': 'EX-99'},
#     {'sequence': '\xa0',
#      'size': '809675',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046904000019/0000730469-04-000019.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '0000730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': '10-K/A',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '04634363'}],
#    'id': '994a45ef8feb17ca6a14c688bcd0cfa6',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-04-000019-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [],
#    'periodOfReport': '2002-12-31'},
#   {'ticker': 'ALO',
#    'formType': '10-K',
#    'accessionNo': '0000730469-03-000001',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/alo10k.htm',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/0000730469-03-000001.txt',
#    'filedAt': '2003-03-24T13:33:36-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '798344',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/alo10k.htm',
#      'description': 'FORM 10K FOR YEAR ENDED DECEMBER 31, 2002',
#      'type': '10-K'},
#     {'sequence': '3',
#      'size': '40085',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/bankamend10-3.htm',
#      'description': 'AMENDMENT NO. 1 TO THE CREDIT AGREEMENT',
#      'type': 'EX-10.3'},
#     {'sequence': '4',
#      'size': '7952',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/valentino10-15.htm',
#      'description': 'SEPARATION AGREEMENT',
#      'type': 'EX-10.15'},
#     {'sequence': '5',
#      'size': '7046',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/wrenn10-16.htm',
#      'description': 'EMPLOYMENT CONTRACT',
#      'type': 'EX-10.16'},
#     {'sequence': '6',
#      'size': '8276',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/roseoffer10-17.htm',
#      'description': 'EMPLOYMENT CONTRACT',
#      'type': 'EX-10.17'},
#     {'sequence': '7',
#      'size': '8220',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/cac10-18.htm',
#      'description': 'EMPLOYMENT CONTRACT',
#      'type': 'EX-10.18'},
#     {'sequence': '8',
#      'size': '30997',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/espp10-20.htm',
#      'description': 'AMENDED AND RESTATED EMPLOYEE STOCK PURCHASE PLAN',
#      'type': 'EX-10.20'},
#     {'sequence': '9',
#      'size': '27756',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/severance10-21.htm',
#      'description': 'SEVERANCE PLAN',
#      'type': 'EX-10.21'},
#     {'sequence': '10',
#      'size': '33260',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/cocplan10-22.htm',
#      'description': 'CHANGE IN CONTROL PLAN',
#      'type': 'EX-10.22'},
#     {'sequence': '11',
#      'size': '18634',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/bonusplan10-23.htm',
#      'description': 'EXECUTIVE BONUS PLAN',
#      'type': 'EX-10.23'},
#     {'sequence': '12',
#      'size': '66109',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/saleagre10-28.htm',
#      'description': 'AGREEMENT OF SALE BETWEEN ALPHARMA AS AND NOPAL AS',
#      'type': 'EX-10.28'},
#     {'sequence': '13',
#      'size': '30327',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/supply10-29.htm',
#      'description': 'SUPPLY AND PACKAGING AGREEMENT',
#      'type': 'EX-10.29'},
#     {'sequence': '14',
#      'size': '36341',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/medical10-30.htm',
#      'description': 'DISTRIBUTION AGREEMENT FOR MEDICAL PLASTER PRODUCTS',
#      'type': 'EX-10.30'},
#     {'sequence': '15',
#      'size': '33205',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046903000001/vitamin10-31.htm',
#      'description': 'DISTRIBUTION AGREEMENT FOR VITAMIN PRODUCTS',
#      'type': 'EX-10.31'},
#     {'sequence': '16',
# ...
#      'filmNo': '769724',
#      'sic': '2834 Pharmaceutical Preparations'}],
#    'documentFormatFiles': [{'sequence': '1',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046900000009/0000730469-00-000009-0001.txt',
#      'type': '10-K/A',
#      'size': '260634'},
#     {'sequence': '2',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046900000009/0000730469-00-000009-0002.txt',
#      'type': 'EX-27',
#      'size': '2016'},
#     {'sequence': '3',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046900000009/0000730469-00-000009-0003.txt',
#      'type': 'EX-23',
#      'size': '606'},
#     {'sequence': '\xa0',
#      'description': 'Complete submission text file',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046900000009/0000730469-00-000009.txt',
#      'type': '\xa0',
#      'size': '265056'}],
#    'dataFiles': [],
#    'periodOfReport': '1999-12-31'},
#   {'id': 'c8f07cb5a91a390d862be644dd62c8d3',
#    'accessionNo': '0000730469-00-000002',
#    'cik': '730469',
#    'ticker': 'ALO',
#    'companyName': 'ALPHARMA INC',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'formType': '10-K',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'filedAt': '2000-03-29T00:00:00-05:00',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000073046900000002/0000730469-00-000002.txt',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-00-000002-index.htm',
#    'linkToXbrl': '',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000073046900000002/',
#    'entities': [{'companyName': 'ALPHARMA INC (Filer)',
#      'cik': '0000730469',
#      'irsNo': '222095212',
#      'stateOfIncorporation': 'DE',
#      'fiscalYearEnd': '1231',
#      'type': '10-K',
#      'act': '34',
#      'fileNo': '001-08593',
#      'filmNo': '582353',
#      'sic': '2834 Pharmaceutical Preparations'}],
#    'documentFormatFiles': [{'sequence': '1',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046900000002/',
#      'type': '10-K',
#      'size': '251559'},
#     {'sequence': '2',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046900000002/',
#      'type': 'EX-10',
#      'size': '6596'},
#     {'sequence': '3',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046900000002/',
#      'type': 'EX-21',
#      'size': '1690'},
#     {'sequence': '4',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046900000002/',
#      'type': 'EX-23',
#      'size': '556'},
#     {'sequence': '5',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046900000002/',
#      'type': 'EX-27',
#      'size': '2005'},
#     {'sequence': '\xa0',
#      'description': 'Complete submission text file',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/000073046900000002/0000730469-00-000002.txt',
#      'type': '\xa0',
#      'size': '264120'}],
#    'dataFiles': [],
#    'periodOfReport': '1999-12-31'},
#   {'ticker': 'ALO',
#    'formType': '10-K',
#    'accessionNo': '0000730469-99-000001',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'effectivenessDate': '1998-12-31',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-99-000001.txt',
#    'filedAt': '1999-03-26T00:00:00-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '256902',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '259777',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '3',
#      'size': '1935',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-21'},
#     {'sequence': '4',
#      'size': '985',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-23'},
#     {'sequence': '5',
#      'size': '2020',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-27'},
#     {'sequence': '6',
#      'size': '82706',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '\xa0',
#      'size': '606103',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-99-000001.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '1998-12-31',
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': '10-K',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '99573856'}],
#    'id': '2dc70a2be90f10c0b813302783c1af1d',
#    'seriesAndClassesContractsInformation': [],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-99-000001-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': []},
#   {'ticker': 'ALO',
#    'formType': '10-K',
#    'accessionNo': '0000730469-98-000001',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-98-000001.txt',
#    'filedAt': '1998-03-09T00:00:00-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '221634',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '32260',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '3',
#      'size': '32545',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '4',
#      'size': '1617',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-21'},
#     {'sequence': '5',
#      'size': '925',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-23'},
#     {'sequence': '6',
#      'size': '2020',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-27'},
#     {'sequence': '\xa0',
#      'size': '292792',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-98-000001.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '1997-12-31',
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': '10-K',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '98559978'}],
#    'id': 'bd0ae3a07fe1bcdb9ea5dd5678376a67',
#    'seriesAndClassesContractsInformation': [],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-98-000001-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': []},
#   {'ticker': 'ALO',
#    'formType': '10-K',
#    'accessionNo': '0000730469-97-000002',
#    'cik': '730469',
#    'companyNameLong': 'ALPHARMA INC (Filer)',
#    'companyName': 'ALPHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-97-000002.txt',
#    'filedAt': '1997-03-24T00:00:00-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '204682',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '33041',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '3',
#      'size': '2113',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '4',
#      'size': '10396',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '5',
#      'size': '2498',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-11'},
#     {'sequence': '6',
#      'size': '1523',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-21'},
#     {'sequence': '7',
#      'size': '907',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-23'},
#     {'sequence': '8',
#      'size': '2424',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-27'},
#     {'sequence': '\xa0',
#      'size': '259507',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-97-000002.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '1996-12-31',
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'ALPHARMA INC (Filer)',
#      'type': '10-K',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '97561642'}],
#    'id': 'f6dfb2b8b333244161c71d487cb1f12e',
#    'seriesAndClassesContractsInformation': [],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-97-000002-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': []},
#   {'ticker': 'ALO',
#    'formType': '10-K',
#    'accessionNo': '0000730469-96-000001',
#    'cik': '730469',
#    'companyNameLong': 'A L PHARMA INC (Filer)',
#    'companyName': 'A L PHARMA INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-96-000001.txt',
#    'filedAt': '1996-03-22T00:00:00-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '199738',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '4964',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '3',
#      'size': '10260',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '4',
#      'size': '26902',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '5',
#      'size': '4677',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '6',
#      'size': '2594',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-11'},
#     {'sequence': '7',
#      'size': '1379',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-21'},
#     {'sequence': '8',
#      'size': '766',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-23'},
#     {'sequence': '9',
#      'size': '2018',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-27'},
#     {'sequence': '\xa0',
#      'size': '255198',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-96-000001.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '1995-12-31',
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'A L PHARMA INC (Filer)',
#      'type': '10-K',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '96537584'}],
#    'id': '193ef249d2dfd7606810988871774b69',
#    'seriesAndClassesContractsInformation': [],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-96-000001-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': []},
#   {'ticker': 'ALO',
#    'formType': '10-K',
#    'accessionNo': '0000730469-95-000002',
#    'cik': '730469',
#    'companyNameLong': 'A L LABORATORIES INC (Filer)',
#    'companyName': 'A L LABORATORIES INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-95-000002.txt',
#    'filedAt': '1995-03-30T00:00:00-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '238597',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '41568',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-3'},
#     {'sequence': '3',
#      'size': '50519',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-3'},
#     {'sequence': '4',
#      'size': '100263',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-4'},
#     {'sequence': '5',
#      'size': '381478',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '6',
#      'size': '86292',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '7',
#      'size': '3232',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '8',
#      'size': '104061',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '9',
#      'size': '22585',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '10',
#      'size': '4695',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '11',
#      'size': '1897',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '12',
#      'size': '1916',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '13',
#      'size': '3877',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-10'},
#     {'sequence': '14',
#      'size': '7326',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-11'},
#     {'sequence': '15',
#      'size': '1818',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-21'},
#     {'sequence': '16',
#      'size': '961',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-23'},
#     {'sequence': '17',
#      'size': '3651',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/',
#      'type': 'EX-27'},
#     {'sequence': '\xa0',
#      'size': '1055794',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-95-000002.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '1994-12-31',
#    'entities': [{'fiscalYearEnd': '1231',
#      'stateOfIncorporation': 'DE',
#      'act': '34',
#      'cik': '730469',
#      'fileNo': '001-08593',
#      'irsNo': '222095212',
#      'companyName': 'A L LABORATORIES INC (Filer)',
#      'type': '10-K',
#      'sic': '2834 Pharmaceutical Preparations',
#      'filmNo': '95525025'}],
#    'id': 'b2c8b44ce3a76cfa4b94f519700e78fd',
#    'seriesAndClassesContractsInformation': [],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/730469/0000730469-95-000002-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': []}]}

# %% [markdown]
# Iterate over everything we need

# %%
def get_all_filings(cik:str):
    """
    Get the filings by CIK
    """

    query = {
        "query": f"cik:{cik} AND formType:\"10-K\"",
        "from": "0",
        "size": "50",
        "sort": [{ "filedAt": { "order": "desc" } }]
    }

    all_filings = []
    from_value = 0
    size_value = int(query['size'])

    while True:
        query['from'] = str(from_value)
        filings = queryApi.get_filings(query)
        
        # Add current batch of filings to the all_filings list
        all_filings.extend(filings['filings'])
        
        # Check if the relation is not 'gte', break the loop
        if filings['total']['relation'] != 'gte':
            break
        
        # Increment the from value by size for the next iteration
        from_value += size_value

    return all_filings

# %%
all_filings = get_all_filings("730469")

# %%
len(all_filings)
# Out:
# 21

# %%
all_filings_all_dict = {cik: get_all_filings(cik) for cik in cik_values} # halved everything should take about 5 minutes instead.

# %%
all_filings_all_dict # 14 s get the first 5 values in a dictionary later for details - and simplify it!!

# %%
all_filings_all_dict['730469']

# %%
with open("annual_report_data/all_companies_report_metadata.json", "w", encoding="utf-8") as file:

    json.dump(all_filings_all_dict, file)

# %%
# run that and wait to get everything that's it!!

# %%
# get dictionary with only the report link for extraction api - use this for later for extraction

# no need just separate and enrich for each json

# %% [markdown]
# 2. Then get the url for the special section for the report that's needed
#
# Once you get the dictionary then save the json, and then find the json details and call the corresponding api that follows

# %%
from sec_api import ExtractorApi

extractorApi = ExtractorApi(API_KEY)

# %%
# get the relevant filings for a particular document for each file - and save the details

all_filings_all_dict['730469']

# %%
report_url = all_filings_all_dict['730469'][0]["linkToFilingDetails"] #filings["filings"][0]["linkToFilingDetails"]

# %%
section_text = extractorApi.get_section(report_url, "1", "text")
print(section_text)

# %%
risk_section_text = extractorApi.get_section(report_url, "1A", "text")
print(risk_section_text)

# %% [markdown]
# ## Convert for each dictionary a single report for each for review
#
# - Format each later for review
#
# - Add document topics based on unique id.

# %%
all_filings_all_dict['730469'][2].keys()

# %%
all_filings_all_dict

# %%
[{'ticker': 'ALO',
  'formType': '10-K',
  'accessionNo': '0000730469-08-000102',
  'cik': '730469',
  'companyNameLong': 'ALPHARMA INC (Filer)',
  'companyName': 'ALPHARMA INC',
  'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/alpharmainc_10k.htm',
  'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
  'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/730469/000073046908000102/0000730469-08-000102.txt',
  'filedAt': '2008-02-27T14:45:30-05:00',}
]

# %% [markdown]
# ## Conclusion
#
# Can run everything as is with the data here, and just filter the data at the end to run the relevant analytics
#
# Text analysis
#
# - Look at general overview and risk factors for overview structure for this.
#
#
# ### Data storage
#
# cik 1 and 1A for other details later. include a filed at here.
#
#
# How to filter details - put relevant graph details for all of them, must have a meaningful way to filter these.
